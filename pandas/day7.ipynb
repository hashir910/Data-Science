# %%
import pandas as pd
import numpy as np

cof= pd.read_csv('../warmup-data/coffee.csv')
cof
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
cof.loc[3:6,'Units Sold']=np.nan
cof
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso        25.0
# 1      Monday       Latte        15.0
# 2     Tuesday    Espresso        30.0
# 3     Tuesday       Latte         NaN
# 4   Wednesday    Espresso         NaN
# 5   Wednesday       Latte         NaN
# 6    Thursday    Espresso         NaN
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0

# %%
# cof[cof['Units Sold'].isna()]

# cof.isna().sum()

# %%
# cof['Units Sold']=cof['Units Sold'].fillna(cof['Units Sold'].mean())
# cof

# %%
cof.dropna(subset=['Units Sold'],inplace=True)
cof
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso        25.0
# 1      Monday       Latte        15.0
# 2     Tuesday    Espresso        30.0
# 3     Tuesday       Latte         NaN
# 4   Wednesday    Espresso         NaN
# 5   Wednesday       Latte         NaN
# 6    Thursday    Espresso         NaN
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0
