# %%
import pandas as pd
import numpy as np


df=pd.read_csv('../data/bios.csv')
df
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
df.head(5)[df['name'].str.endswith('n')]
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_2924\858639855.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.head(5)[df['name'].str.endswith('n')]
#    athlete_id             name   born_date    born_city born_region  \
# 3           4  Jacques Brugnon  1895-05-11  Paris VIIIe       Paris
#
#   born_country     NOC  height_cm  weight_kg   died_date
# 3          FRA  France      168.0       64.0  1978-03-20

# %%
df[(df['height_cm']>170)&(df['born_region']=='Paris') & (df['name'].str.contains('J')) & (df['athlete_id']<20000)].dropna()
# Out:
#        athlete_id                name   born_date  born_city born_region  \
# 3054         3066       Jacques Marty  1940-07-30  Paris XXe       Paris
# 12006       12071  Jean-Jacques Guyon  1932-12-21  Paris XVe       Paris
# 17780       17901      Joseph Olivier  1874-12-02  Paris VIe       Paris
# 18466       18592     Jean Desmasures  1928-08-29  Paris XVe       Paris
#
#       born_country     NOC  height_cm  weight_kg   died_date
# 3054           FRA  France      178.0       75.0  2012-08-02
# 12006          FRA  France      171.0       60.0  2017-12-20
# 17780          FRA  France      180.0       74.0  1901-05-21
# 18466          FRA  France      183.0       78.0  2012-04-29

# %%
df[(df['name'].str.startswith(('J','N'))) & (df['born_country'].isin(['FRA','USA']))]
# Out:
#         athlete_id                   name   born_date    born_city  \
# 0                1  Jean-François Blanchy  1886-12-12     Bordeaux
# 2                3           Jean Borotra  1898-08-13     Biarritz
# 3                4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 5                6      Nicolas Chatelain  1970-01-13       Amiens
# 17              18   Jean-Philippe Gatien  1968-10-16         Alès
# ...            ...                    ...         ...          ...
# 145421      149144           Nathan Smith  1998-10-19        Tampa
# 145424      149147     Jonathan Gustafson  1997-03-05      Massena
# 145427      149150          Jared Shumate  1999-03-06      Atlanta
# 145444      149167            Julie Letai  2000-06-23     Medfield
# 145468      149195      Justin Abdelkader  1987-02-25     Muskegon
#
#                  born_region born_country            NOC  height_cm  \
# 0                    Gironde          FRA         France        NaN
# ...

# %%
df['height_cm'][(df['name'].str.startswith(('J','N'))) & (df['born_country'].isin(['FRA','USA']))]=0
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_2924\276977157.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['height_cm'][(df['name'].str.startswith(('J','N'))) & (df['born_country'].isin(['FRA','USA']))]=0
# ...

# %%
df
