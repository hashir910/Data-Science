# %%
import pandas as pd
import numpy as np

coffee=pd.read_csv('../warmup-data/coffee.csv')
bios=pd.read_csv('../data/bios.csv')
results=pd.read_csv('../data/results.csv')
results
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
# ...

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee['rank']=coffee['Units Sold'].rank(ascending=True)
coffee[coffee['Coffee Type']=='Latte'].sort_values('rank',ascending=False)
# Out:
#           Day Coffee Type  Units Sold  rank
# 13     Sunday       Latte          35   8.5
# 11   Saturday       Latte          35   8.5
# 9      Friday       Latte          35   8.5
# 7    Thursday       Latte          30   5.5
# 5   Wednesday       Latte          25   3.5
# 3     Tuesday       Latte          20   2.0
# 1      Monday       Latte          15   1.0

# %%
coffee['shifting']=coffee['Units Sold'].shift(1)
coffee
# Out:
#           Day Coffee Type  Units Sold  rank  shifting
# 0      Monday    Espresso          25   3.5       NaN
# 1      Monday       Latte          15   1.0      25.0
# 2     Tuesday    Espresso          30   5.5      15.0
# 3     Tuesday       Latte          20   2.0      30.0
# 4   Wednesday    Espresso          35   8.5      20.0
# 5   Wednesday       Latte          25   3.5      35.0
# 6    Thursday    Espresso          40  11.0      25.0
# 7    Thursday       Latte          30   5.5      40.0
# 8      Friday    Espresso          45  13.0      30.0
# 9      Friday       Latte          35   8.5      45.0
# 10   Saturday    Espresso          45  13.0      35.0
# 11   Saturday       Latte          35   8.5      45.0
# 12     Sunday    Espresso          45  13.0      35.0
# 13     Sunday       Latte          35   8.5      45.0

# %%
latte=coffee[coffee['Coffee Type']=='Latte']
latte['shifting']=latte['Units Sold'].rolling(1).sum()
latte
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12872\1710518357.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   latte['shifting']=latte['Units Sold'].rolling(1).sum()
#           Day Coffee Type  Units Sold  rank  shifting  rolling
# 1      Monday       Latte          15   1.0      15.0     40.0
# 3     Tuesday       Latte          20   2.0      20.0     50.0
# 5   Wednesday       Latte          25   3.5      25.0     60.0
# 7    Thursday       Latte          30   5.5      30.0     70.0
# 9      Friday       Latte          35   8.5      35.0     80.0
# 11   Saturday       Latte          35   8.5      35.0     80.0
# 13     Sunday       Latte          35   8.5      35.0     80.0

# %%
coffee['rolling 3days']=coffee['Units Sold'].rolling(3).sum()
coffee[coffee['Coffee Type']=='Latte']
# Out:
#           Day Coffee Type  Units Sold  rank  shifting  rolling  rolling 3days
# 1      Monday       Latte          15   1.0      25.0     40.0            NaN
# 3     Tuesday       Latte          20   2.0      30.0     50.0           65.0
# 5   Wednesday       Latte          25   3.5      35.0     60.0           80.0
# 7    Thursday       Latte          30   5.5      40.0     70.0           95.0
# 9      Friday       Latte          35   8.5      45.0     80.0          110.0
# 11   Saturday       Latte          35   8.5      45.0     80.0          115.0
# 13     Sunday       Latte          35   8.5      45.0     80.0          115.0

# %%
df=coffee.groupby('Coffee Type').get_group('Latte')['Units Sold'].rolling(3).sum()
df
# Out:
# 1       NaN
# 3       NaN
# 5      60.0
# 7      75.0
# 9      90.0
# 11    100.0
# 13    105.0
# Name: Units Sold, dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12872\3391913210.py in ?()
# ----> 1 coffee.get_group('Coffee Type').rolling(3).sum()
#
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'get_group'
