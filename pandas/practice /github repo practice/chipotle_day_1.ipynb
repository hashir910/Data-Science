# %% [markdown]
# <a href="https://colab.research.google.com/github/hashir910/Data-Science/blob/main/pandas/practice%20/github%20repo%20practice/chipotle_day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# step 1

# %%
import pandas as pd
import numpy as np
url='https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
chipo=pd.read_csv(url,sep = '\t')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
chipo.shape[1]
# Out:
# 5

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
chipo.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
# data set is indexed by user id
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
for i in chipo.columns:
  print(i)
# Out:
# order_id
# quantity
# item_name
# choice_description
# item_price

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
# chipo.groupby('item_name')['quantity'].sum().max()
chipo.groupby('item_name')['quantity'].sum().sort_values(ascending=False).head(1)
# Out:
# item_name
# Chicken Bowl    761
# Name: quantity, dtype: int64

# %%
most_ordered_item=chipo.groupby('item_name').sum().sort_values(['quantity'],ascending=False).head(1)[['quantity','order_id']]
most_ordered_item

# c = chipo.groupby('item_name')
# c = c.sum()
# c = c.sort_values(['quantity'], ascending=False)
# c.head(1)
# Out:
#               quantity  order_id
# item_name
# Chicken Bowl       761    713926

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
kbd=chipo.groupby('choice_description').sum().sort_values(['quantity'],ascending=False).head(1)
kbd
# Out:
#                     order_id  quantity  \
# choice_description
# [Diet Coke]           123455       159
#
#                                                             item_name  \
# choice_description
# [Diet Coke]         Canned SodaCanned SodaCanned Soda6 Pack Soft D...
#
#                                                            item_price
# choice_description
# [Diet Coke]         $2.18 $1.09 $1.09 $6.49 $2.18 $1.25 $1.09 $6.4...

# %%
# k=chipo['item_price'].str.strip('$')
# k.astype(float)
# chipo['item_price']=k

# chipo.head()

itemprice=chipo['item_price'].apply(lambda x: x.strip('$'))
itemprice=itemprice.astype(float)
chipo['item_price']=itemprice
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-664230089.py in <cell line: 0>()
#       5 # chipo.head()
#       6
# ----> 7 itemprice=chipo['item_price'].apply(lambda x: x.strip('$'))
#       8 itemprice=itemprice.astype(float)
#       9 chipo['item_price']=itemprice
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply_standard(self)
# ...

# %%
revenue=chipo['item_price'].sum()
np.round(revenue)
# Out:
# np.float64(34500.0)

# %%
totalorders=chipo['order_id'].value_counts().count()
totalorders
# Out:
# np.int64(1834)

# %%
avgrev=chipo['item_price']*chipo['quantity']
avgrev
# Out:
# 0       11883.08
# 1       16855.08
# 2       16855.08
# 3       11883.08
# 4       84424.56
#           ...
# 4617    58421.00
# 4618    58421.00
# 4619    55935.00
# 4620    43505.00
# 4621    43505.00
# Name: item_price, Length: 4622, dtype: float64
